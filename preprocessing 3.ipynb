# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Extracting features of 2018 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 243  D E C E M B E R         21               Second Act
# 244  D E C E M B E R         25          Holmes & Watson
# 245  D E C E M B E R         25                     Vice
# 246  D E C E M B E R         25      On the Basis of Sex
# 247  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 243                                  STX Entertainment
# 244  Columbia Pictures / Gary Sanchez Productions /...
# 245          Annapurna Pictures / Plan B Entertainment
# 246                                     Focus Features
# 247                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 243  Peter Segal (director); Justin Zackham, Elaine...  [237]
# 244  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 245  Adam McKay (director/screenplay); Christian Ba...  [117]
# 246  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 247  Karyn Kusama (director); Phil Hay, Matt Manfre...  [238]
#
# [248 rows x 6 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in /opt/anaconda3/lib/python3.12/site-packages (1.9.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from tmdbv3api) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->tmdbv3api) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->tmdbv3api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->tmdbv3api) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->tmdbv3api) (2024.6.2)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'YOUR_API_KEY'

# %%
print(tmdb.api_key)
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN
# Out:
# b44755bc2d64d14e42e7e3cb09fde828

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#              Opening  Opening.1                    Title  \
# 0      J A N U A R Y          5  Insidious: The Last Key
# 1      J A N U A R Y          5         The Strange Ones
# 2      J A N U A R Y         12             The Commuter
# 3      J A N U A R Y         12               Proud Mary
# 4      J A N U A R Y         12         Acts of Violence
# ..               ...        ...                      ...
# 243  D E C E M B E R         21               Second Act
# 244  D E C E M B E R         25          Holmes & Watson
# 245  D E C E M B E R         25                     Vice
# 246  D E C E M B E R         25      On the Basis of Sex
# 247  D E C E M B E R         25                Destroyer
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2        Lionsgate / StudioCanal / The Picture Company
# 3                                          Screen Gems
# 4                                   Lionsgate Premiere
# ..                                                 ...
# 243                                  STX Entertainment
# 244  Columbia Pictures / Gary Sanchez Productions /...
# 245          Annapurna Pictures / Plan B Entertainment
# 246                                     Focus Features
# 247                                 Annapurna Pictures
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Christopher Radcliff (director/screenplay); La...    [3]
# 2    Jaume Collet-Serra (director); Byron Willinger...    [4]
# 3    Babak Najafi (director); John S. Newman, Chris...    [5]
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...    [6]
# ..                                                 ...    ...
# 243  Peter Segal (director); Justin Zackham, Elaine...  [237]
# 244  Etan Cohen (director/screenplay); Will Ferrell...  [142]
# 245  Adam McKay (director/screenplay); Christian Ba...  [117]
# 246  Mimi Leder (director); Daniel Stiepleman (scre...  [207]
# 247  Karyn Kusama (director); Phil Hay, Matt Manfre...  [238]
#
#                                         genres
# 0                              Horror Thriller
# 1                                Drama Mystery
# 2                      Action Thriller Mystery
# 3                        Thriller Action Crime
# 4                        Action Crime Thriller
# ..                                         ...
# 243                             Romance Comedy
# 244             Mystery Adventure Comedy Crime
# 245  Thriller Science Fiction Action Adventure
# 246                              Drama History
# 247                Thriller Crime Drama Action
#
# [248 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 243               Second Act
# 244          Holmes & Watson
# 245                     Vice
# 246      On the Basis of Sex
# 247                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 243  Peter Segal (director); Justin Zackham, Elaine...
# 244  Etan Cohen (director/screenplay); Will Ferrell...
# 245  Adam McKay (director/screenplay); Christian Ba...
# 246  Mimi Leder (director); Daniel Stiepleman (scre...
# 247  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                                         genres
# 0                              Horror Thriller
# 1                                Drama Mystery
# 2                      Action Thriller Mystery
# 3                        Thriller Action Crime
# 4                        Action Crime Thriller
# ..                                         ...
# 243                             Romance Comedy
# 244             Mystery Adventure Comedy Crime
# 245  Thriller Science Fiction Action Adventure
# 246                              Drama History
# 247                Thriller Crime Drama Action
#
# [248 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# /var/folders/fh/vq_84pxn32d0lthgylg5kw900000gn/T/ipykernel_88370/930721595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /var/folders/fh/vq_84pxn32d0lthgylg5kw900000gn/T/ipykernel_88370/2274966287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# /var/folders/fh/vq_84pxn32d0lthgylg5kw900000gn/T/ipykernel_88370/3672495884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                        Title  \
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 243               Second Act
# 244          Holmes & Watson
# 245                     Vice
# 246      On the Basis of Sex
# 247                Destroyer
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Christopher Radcliff (director/screenplay); La...
# 2    Jaume Collet-Serra (director); Byron Willinger...
# 3    Babak Najafi (director); John S. Newman, Chris...
# 4    Brett Donowho (director); Nicolas Aaron Mezzan...
# ..                                                 ...
# 243  Peter Segal (director); Justin Zackham, Elaine...
# 244  Etan Cohen (director/screenplay); Will Ferrell...
# 245  Adam McKay (director/screenplay); Christian Ba...
# 246  Mimi Leder (director); Daniel Stiepleman (scre...
# 247  Karyn Kusama (director); Phil Hay, Matt Manfre...
#
#                                         genres  \
# 0                              Horror Thriller
# 1                                Drama Mystery
# 2                      Action Thriller Mystery
# 3                        Thriller Action Crime
# 4                        Action Crime Thriller
# ..                                         ...
# 243                             Romance Comedy
# 244             Mystery Adventure Comedy Crime
# 245  Thriller Science Fiction Action Adventure
# 246                              Drama History
# 247                Thriller Crime Drama Action
#
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 243                                        Peter Segal
# 244                                         Etan Cohen
# 245                                         Adam McKay
# 246                                         Mimi Leder
# 247                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 243                              Jennifer Lopez             Leah Remini
# 244                                Will Ferrell          John C. Reilly
# 245                              Christian Bale               Amy Adams
# 246                              Felicity Jones            Armie Hammer
# 247                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name
# 0     Leigh Whannell
# 1      Emily Althaus
# 2     Patrick Wilson
# 3        Billy Brown
# 4      Shawn Ashmore
# ..               ...
# 243  Vanessa Hudgens
# 244     Rebecca Hall
# 245     Steve Carell
# 246   Justin Theroux
# 247     Toby Kebbell
#
# [248 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 243                                        Peter Segal
# 244                                         Etan Cohen
# 245                                         Adam McKay
# 246                                         Mimi Leder
# 247                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 243                              Jennifer Lopez             Leah Remini
# 244                                Will Ferrell          John C. Reilly
# 245                              Christian Bale               Amy Adams
# 246                              Felicity Jones            Armie Hammer
# 247                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name                                     genres  \
# 0     Leigh Whannell                            Horror Thriller
# 1      Emily Althaus                              Drama Mystery
# 2     Patrick Wilson                    Action Thriller Mystery
# 3        Billy Brown                      Thriller Action Crime
# 4      Shawn Ashmore                      Action Crime Thriller
# ..               ...                                        ...
# 243  Vanessa Hudgens                             Romance Comedy
# 244     Rebecca Hall             Mystery Adventure Comedy Crime
# 245     Steve Carell  Thriller Science Fiction Action Adventure
# 246   Justin Theroux                              Drama History
# 247     Toby Kebbell                Thriller Crime Drama Action
#
#                  movie_title
# 0    Insidious: The Last Key
# 1           The Strange Ones
# 2               The Commuter
# 3                 Proud Mary
# 4           Acts of Violence
# ..                       ...
# 243               Second Act
# 244          Holmes & Watson
# 245                     Vice
# 246      On the Basis of Sex
# 247                Destroyer
#
# [248 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#                                          director_name  \
# 0                                         Adam Robitel
# 1    Christopher Radcliff (director/screenplay); La...
# 2                                   Jaume Collet-Serra
# 3                                         Babak Najafi
# 4                                        Brett Donowho
# ..                                                 ...
# 243                                        Peter Segal
# 244                                         Etan Cohen
# 245                                         Adam McKay
# 246                                         Mimi Leder
# 247                                       Karyn Kusama
#
#                                    actor_1_name            actor_2_name  \
# 0                                     Lin Shaye           Angus Sampson
# 1    Lauren Wolkstein (director); Alex Pettyfer  James Freedson-Jackson
# 2                                   Liam Neeson            Vera Farmiga
# 3                              Taraji P. Henson    Jahi Di'Allo Winston
# 4                                  Bruce Willis             Cole Hauser
# ..                                          ...                     ...
# 243                              Jennifer Lopez             Leah Remini
# 244                                Will Ferrell          John C. Reilly
# 245                              Christian Bale               Amy Adams
# 246                              Felicity Jones            Armie Hammer
# 247                               Nicole Kidman          Sebastian Stan
#
#         actor_3_name                                     genres  \
# 0     Leigh Whannell                            Horror Thriller
# 1      Emily Althaus                              Drama Mystery
# 2     Patrick Wilson                    Action Thriller Mystery
# 3        Billy Brown                      Thriller Action Crime
# 4      Shawn Ashmore                      Action Crime Thriller
# ..               ...                                        ...
# 243  Vanessa Hudgens                             Romance Comedy
# 244     Rebecca Hall             Mystery Adventure Comedy Crime
# 245     Steve Carell  Thriller Science Fiction Action Adventure
# 246   Justin Theroux                              Drama History
# 247     Toby Kebbell                Thriller Crime Drama Action
#
#                  movie_title  \
# 0    insidious: the last key
# 1           the strange ones
# 2               the commuter
# 3                 proud mary
# 4           acts of violence
# ..                       ...
# 243               second act
# 244          holmes & watson
# 245                     vice
# 246      on the basis of sex
# 247                destroyer
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Lauren Wolkstein (director); Alex Pettyfer Jam...
# 2    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# 3    Taraji P. Henson Jahi Di'Allo Winston Billy Br...
# 4    Bruce Willis Cole Hauser Shawn Ashmore Brett D...
# ..                                                 ...
# 243  Jennifer Lopez Leah Remini Vanessa Hudgens Pet...
# 244  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 245  Christian Bale Amy Adams Steve Carell Adam McK...
# 246  Felicity Jones Armie Hammer Justin Theroux Mim...
# 247  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
#
# [248 rows x 7 columns]

# %% [markdown]
# ## Extracting features of 2019 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                Title  \
# 0          A P R I L        5.0              Shazam!
# 1          A P R I L        5.0         Pet Sematary
# 2          A P R I L        5.0  The Best of Enemies
# 3          A P R I L        5.0            High Life
# 4          A P R I L        5.0        Unicorn Store
# ..               ...        ...                  ...
# 196  D E C E M B E R       25.0         Little Women
# 197  D E C E M B E R       25.0                 1917
# 198  D E C E M B E R       25.0           Just Mercy
# 199  D E C E M B E R       27.0             Clemency
# 200              NaN        NaN                  NaN
#
#                                     Production company  \
# 0    Warner Bros. Pictures / New Line Cinema / DC F...
# 1                  Paramount Pictures / Room 101, Inc.
# 2                                    STX Entertainment
# 3                    A24 / Arte / ZDF / Canal+ / Ciné+
# 4                                              Netflix
# ..                                                 ...
# 196            Columbia Pictures / Regency Enterprises
# 197           Universal Pictures / DreamWorks Pictures
# 198          Warner Bros. Pictures / Participant Media
# 199                                               Neon
# 200                                                NaN
#
#                                          Cast and crew   Ref.  \
# 0    David F. Sandberg (director); Henry Gayden (sc...   [51]
# 1    Kevin Kolsch, Dennis Widmyer (directors); Jeff...   [52]
# 2    Robin Bissell (director/screenplay); Taraji P....   [53]
# 3    Claire Denis (director/screenplay); Jean-Pol F...   [54]
# 4    Brie Larson (director); Samantha McIntyre (scr...    NaN
# ..                                                 ...    ...
# 196  Greta Gerwig (director/screenplay); Saoirse Ro...  [226]
# 197  Sam Mendes (director/screenplay); Krysty Wilso...  [227]
# 198  Destin Daniel Cretton (director/screenplay), A...  [228]
# 199  Chinonye Chukwu (director/screenplay); Alfre W...  [229]
# 200                                                NaN    NaN
#
#                                          vte2019 films  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
# 200  American Argentine Australian Bangladeshi Braz...
#
#                                        vte2019 films.1
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
# 200  American Argentine Australian Bangladeshi Braz...
#
# [201 rows x 8 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                    Title                                      Cast and crew  \
# 0                Shazam!  David F. Sandberg (director); Henry Gayden (sc...
# 1           Pet Sematary  Kevin Kolsch, Dennis Widmyer (directors); Jeff...
# 2    The Best of Enemies  Robin Bissell (director/screenplay); Taraji P....
# 3              High Life  Claire Denis (director/screenplay); Jean-Pol F...
# 4          Unicorn Store  Brie Larson (director); Samantha McIntyre (scr...
# ..                   ...                                                ...
# 196         Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 197                 1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 198           Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 199             Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
# 200                  NaN                                                NaN
#
#                             genres
# 0            Action Comedy Fantasy
# 1                  Horror Thriller
# 2                    Drama History
# 3    Science Fiction Drama Mystery
# 4             Fantasy Drama Comedy
# ..                             ...
# 196          Drama Romance History
# 197       War Action Drama History
# 198            Drama Crime History
# 199                          Drama
# 200                    Drama Crime
#
# [201 rows x 3 columns]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# /var/folders/fh/vq_84pxn32d0lthgylg5kw900000gn/T/ipykernel_88370/203239715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:4700, in Series.map(self, arg, na_action)
#    4620 def map(
#    4621     self,
#    4622     arg: Callable | Mapping | Series,
#    4623     na_action: Literal["ignore"] | None = None,
#    4624 ) -> Series:
#    4625     """
#    4626     Map values of Series according to an input mapping or function.
#    4627
#    (...)
#    4698     dtype: object
#    4699     """
# -> 4700     new_values = self._map_values(arg, na_action=na_action)
#    4701     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4702         self, method="map"
#    4703     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[47], line 1, in <lambda>(x)
# ----> 1 df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
#
# Cell In[25], line 2, in get_actor1(x)
#       1 def get_actor1(x):
# ----> 2     return ((x.split("screenplay); ")[-1]).split(", ")[0])
#
# AttributeError: 'float' object has no attribute 'split'

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#              director_name         actor_1_name          actor_2_name  \
# 0             Adam Robitel       Taylor Russell          Logan Miller
# 1              Jen McGowan    Hermione Corfield           Jay Paulson
# 2        Wilson Coneybeare    Donald Sutherland    Vincent Kartheiser
# 3     Charles Martin Smith  Bryce Dallas Howard    Edward James Olmos
# 4              Neil Burger       Bryan Cranston            Kevin Hart
# ..                     ...                  ...                   ...
# 236           Greta Gerwig        Saoirse Ronan           Emma Watson
# 237             Sam Mendes        George MacKay  Dean-Charles Chapman
# 238  Destin Daniel Cretton    Michael B. Jordan            Jamie Foxx
# 239        Chinonye Chukwu        Alfre Woodard        Wendell Pierce
# 240           Waymon Boone          Mena Suvari          Kevin Pollak
#
#          actor_3_name                          genres       movie_title  \
# 0    Deborah Ann Woll  Thriller Action Mystery Horror       escape room
# 1        Sean O'Bryan                  Thriller Drama        rust creek
# 2       Oliver Dennis                        Thriller  american hangman
# 3     Alexandra Shipp          Drama Adventure Family  a dog's way home
# 4       Nicole Kidman                    Comedy Drama        the upside
# ..                ...                             ...               ...
# 236     Florence Pugh                   Drama Romance      little women
# 237       Mark Strong        War Drama Action History              1917
# 238       Brie Larson                     Drama Crime        just mercy
# 239       Aldis Hodge                           Drama          clemency
# 240           unknown                 Horror Thriller        apparition
#
#                                                   comb
# 0    Taylor Russell Logan Miller Deborah Ann Woll A...
# 1    Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2    Donald Sutherland Vincent Kartheiser Oliver De...
# 3    Bryce Dallas Howard Edward James Olmos Alexand...
# 4    Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                                                 ...
# 236  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 237  George MacKay Dean-Charles Chapman Mark Strong...
# 238  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 239  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 240  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [241 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)

# %%
my_df
# Out:
#              director_name       actor_1_name            actor_2_name  \
# 0             Adam Robitel          Lin Shaye           Angus Sampson
# 1         Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2               Simon West     Dominic Cooper          Austin Stowell
# 3         Warwick Thornton        Bryan Brown               Sam Neill
# 4       Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                     ...                ...                     ...
# 504           Greta Gerwig      Saoirse Ronan             Emma Watson
# 505             Sam Mendes      George MacKay    Dean-Charles Chapman
# 506  Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 507        Chinonye Chukwu      Alfre Woodard          Wendell Pierce
# 508           Waymon Boone        Mena Suvari            Kevin Pollak
#
#        actor_3_name                    genres              movie_title  \
# 0    Leigh Whannell   Mystery Horror Thriller  insidious: the last key
# 1     Emily Althaus            Thriller Drama         the strange ones
# 2        Gemma Chan           Action Thriller                 stratton
# 3           unknown     Drama History Western            sweet country
# 4    Patrick Wilson           Action Thriller             the commuter
# ..              ...                       ...                      ...
# 504   Florence Pugh             Drama Romance             little women
# 505     Mark Strong  War Drama Action History                     1917
# 506     Brie Larson               Drama Crime               just mercy
# 507     Aldis Hodge                     Drama                 clemency
# 508         unknown           Horror Thriller               apparition
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 504  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 505  George MacKay Dean-Charles Chapman Mark Strong...
# 506  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 507  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 508  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [509 rows x 7 columns]

# %%
old_df = pd.read_csv('../input/movie.csv')

# %%
old_df
# Out:
#          director_name     actor_1_name    actor_2_name     actor_3_name  \
# 0        John Lasseter        Tom Hanks       Tim Allen      Don Rickles
# 1         Joe Johnston   Robin Williams   Jonathan Hyde    Kirsten Dunst
# 2        Howard Deutch   Walter Matthau     Jack Lemmon      Ann-Margret
# 3      Forest Whitaker  Whitney Houston  Angela Bassett   Loretta Devine
# 4        Charles Shyer     Steve Martin    Diane Keaton     Martin Short
# ...                ...              ...             ...              ...
# 36336         Ben Rock       Monty Bane     Lucy Butler    David Grammer
# 36337    Aaron Osborne       Lisa Boyle       Kena Land    Zaneta Polard
# 36338       John Irvin   Patrick Bergin     Uma Thurman  David Morrissey
# 36339         Lav Diaz     Angel Aquino     Perry Dizon    Hazel Orencio
# 36340   Mark L. Lester    Erika Eleniak    Adam Baldwin    Julie du Page
#
#                          genres                  movie_title  \
# 0       Animation Comedy Family                    toy story
# 1      Adventure Fantasy Family                      jumanji
# 2                Romance Comedy             grumpier old men
# 3          Comedy Drama Romance            waiting to exhale
# 4                        Comedy  father of the bride part ii
# ...                         ...                          ...
# 36336                    Horror          the burkittsville 7
# 36337                    Sci-Fi              caged heat 3000
# 36338      Drama Action Romance                   robin hood
# 36339                     Drama          century of birthing
# 36340     Action Drama Thriller                     betrayal
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 36336  Monty Bane Lucy Butler David Grammer Ben Rock ...
# 36337  Lisa Boyle Kena Land Zaneta Polard Aaron Osbor...
# 36338  Patrick Bergin Uma Thurman David Morrissey Joh...
# 36339  Angel Aquino Perry Dizon Hazel Orencio Lav Dia...
# 36340  Erika Eleniak Adam Baldwin Julie du Page Mark ...
#
# [36341 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              John Lasseter          Tom Hanks             Tim Allen
# 1               Joe Johnston     Robin Williams         Jonathan Hyde
# 2              Howard Deutch     Walter Matthau           Jack Lemmon
# 3            Forest Whitaker    Whitney Houston        Angela Bassett
# 4              Charles Shyer       Steve Martin          Diane Keaton
# ...                      ...                ...                   ...
# 36845           Greta Gerwig      Saoirse Ronan           Emma Watson
# 36846             Sam Mendes      George MacKay  Dean-Charles Chapman
# 36847  Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 36848        Chinonye Chukwu      Alfre Woodard        Wendell Pierce
# 36849           Waymon Boone        Mena Suvari          Kevin Pollak
#
#          actor_3_name                    genres                  movie_title  \
# 0         Don Rickles   Animation Comedy Family                    toy story
# 1       Kirsten Dunst  Adventure Fantasy Family                      jumanji
# 2         Ann-Margret            Romance Comedy             grumpier old men
# 3      Loretta Devine      Comedy Drama Romance            waiting to exhale
# 4        Martin Short                    Comedy  father of the bride part ii
# ...               ...                       ...                          ...
# 36845   Florence Pugh             Drama Romance                 little women
# 36846     Mark Strong  War Drama Action History                         1917
# 36847     Brie Larson               Drama Crime                   just mercy
# 36848     Aldis Hodge                     Drama                     clemency
# 36849         unknown           Horror Thriller                   apparition
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 36845  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 36846  George MacKay Dean-Charles Chapman Mark Strong...
# 36847  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 36848  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 36849  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [36850 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           4
# movie_title      0
# comb             4
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.to_csv('final_data.csv',index=False)
